# %% [markdown]
# # Objetivo

# %% [markdown]
# El objetivo de este notebook es recolectar información de las publicaciones del site de MercadoLibre para luego realizar un modelado simple para predecir, dada una publicación, la cantidad de items vendidos. (El modelado se lleva a cabo en el notebook "modelado").
#
# La información se recolecta a través de las APIS publicas de MercadoLibre (https://developers.mercadolibre.com.ar/es_ar/api-docs-es).
#
# Es importante notar que se tomó en cuenta sólo el site de Argentina y sólo las publicaciones bajo la categoría "Celulares y Teléfonos". Se tomaron 1000 publicaciones por cada una de las subcategorías de la categoría "Celulares y Teléfonos".
#
# Este notebook guarda toda la información recolectada en el csv "df_total_original.csv".

# %% [markdown]
# # Índice

# %% [markdown]
# * [1 - Imports](#1)
# * [2 - Recolección de datos](#2)

# %% [markdown]
# # 1 - Imports <a id="1"></a>

# %%
import numpy as np
import pandas as pd

import time
from time import process_time

from funciones import request_a_diccionario, generar_df

# %% [markdown]
# # 2 - Recolección de datos <a id="2"></a>

# %% [markdown]
# #### Analizamos los países que hay

# %%
lista_paises = request_a_diccionario("https://api.mercadolibre.com/sites")

# %%
lista_paises
# Out:
# [{'default_currency_id': 'USD', 'id': 'MSV', 'name': 'El Salvador'},
#  {'default_currency_id': 'MXN', 'id': 'MLM', 'name': 'Mexico'},
#  {'default_currency_id': 'PEN', 'id': 'MPE', 'name': 'Perú'},
#  {'default_currency_id': 'BRL', 'id': 'MLB', 'name': 'Brasil'},
#  {'default_currency_id': 'UYU', 'id': 'MLU', 'name': 'Uruguay'},
#  {'default_currency_id': 'NIO', 'id': 'MNI', 'name': 'Nicaragua'},
#  {'default_currency_id': 'DOP', 'id': 'MRD', 'name': 'Dominicana'},
#  {'default_currency_id': 'GTQ', 'id': 'MGT', 'name': 'Guatemala'},
#  {'default_currency_id': 'COP', 'id': 'MCO', 'name': 'Colombia'},
#  {'default_currency_id': 'PYG', 'id': 'MPY', 'name': 'Paraguay'},
#  {'default_currency_id': 'CLP', 'id': 'MLC', 'name': 'Chile'},
#  {'default_currency_id': 'VES', 'id': 'MLV', 'name': 'Venezuela'},
#  {'default_currency_id': 'CRC', 'id': 'MCR', 'name': 'Costa Rica'},
#  {'default_currency_id': 'HNL', 'id': 'MHN', 'name': 'Honduras'},
#  {'default_currency_id': 'USD', 'id': 'MEC', 'name': 'Ecuador'},
#  {'default_currency_id': 'PAB', 'id': 'MPA', 'name': 'Panamá'},
#  {'default_currency_id': 'ARS', 'id': 'MLA', 'name': 'Argentina'},
#  {'default_currency_id': 'BOB', 'id': 'MBO', 'name': 'Bolivia'},
#  {'default_currency_id': 'CUP', 'id': 'MCU', 'name': 'Cuba'}]

# %% [markdown]
# ### NOTA: vamos a recolectar información sólo de Argentina.

# %% [markdown]
# #### Analizamos las categorías principales que hay

# %%
lista_categorias_principales = request_a_diccionario("https://api.mercadolibre.com/sites/MLA/categories")

# %%
lista_categorias_principales
# Out:
# [{'id': 'MLA5725', 'name': 'Accesorios para Vehículos'},
#  {'id': 'MLA1512', 'name': 'Agro'},
#  {'id': 'MLA1403', 'name': 'Alimentos y Bebidas'},
#  {'id': 'MLA1071', 'name': 'Animales y Mascotas'},
#  {'id': 'MLA1367', 'name': 'Antigüedades y Colecciones'},
#  {'id': 'MLA1368', 'name': 'Arte, Librería y Mercería'},
#  {'id': 'MLA1743', 'name': 'Autos, Motos y Otros'},
#  {'id': 'MLA1384', 'name': 'Bebés'},
#  {'id': 'MLA1246', 'name': 'Belleza y Cuidado Personal'},
#  {'id': 'MLA1039', 'name': 'Cámaras y Accesorios'},
#  {'id': 'MLA1051', 'name': 'Celulares y Teléfonos'},
#  {'id': 'MLA1648', 'name': 'Computación'},
#  {'id': 'MLA1144', 'name': 'Consolas y Videojuegos'},
#  {'id': 'MLA1276', 'name': 'Deportes y Fitness'},
#  {'id': 'MLA5726', 'name': 'Electrodomésticos y Aires Ac.'},
#  {'id': 'MLA1000', 'name': 'Electrónica, Audio y Video'},
#  {'id': 'MLA2547', 'name': 'Entradas para Eventos'},
#  {'id': 'MLA407134', 'name': 'Herramientas y Construcción'},
#  {'id': 'MLA1574', 'name': 'Hogar, Muebles y Jardín'},
#  {'id': 'MLA1499', 'name': 'Industrias y Oficinas'},
#  {'id': 'MLA1459', 'name': 'Inmuebles'},
#  {'id': 'MLA1182', 'name': 'Instrumentos Musicales'},
#  {'id': 'MLA3937', 'name': 'Joyas y Relojes'},
#  {'id': 'MLA1132', 'name': 'Juegos y Juguetes'},
#  {'id': 'MLA3025', 'name': 'Libros, Revistas y Comics'},
#  {'id': 'MLA1168', 'name': 'Música, Películas y Series'},
#  {'id': 'MLA1430', 'name': 'Ropa y Accesorios'},
#  {'id': 'MLA409431', 'name': 'Salud y Equipamiento Médico'},
#  {'id': 'MLA1540', 'name': 'Servicios'},
#  {'id': 'MLA9304', 'name': 'Souvenirs, Cotillón y Fiestas'},
#  {'id': 'MLA1953', 'name': 'Otras categorías'}]

# %%
print("Hay un total de", len(lista_categorias_principales), "categorías principales.")
# Out:
# Hay un total de 31 categorías principales.

# %% [markdown]
# ### NOTA: vamos a recolectar información sólo de la categoría "Celulares y Teléfonos"

# %% [markdown]
# #### Analizamos todas las subcategorías "hoja" de la categoría "Celulares y Teléfonos".

# %%
categorias_all = request_a_diccionario("https://api.mercadolibre.com/sites/MLA/categories/all")

# %%
lista_subcategorias_id = []
lista_subcategorias_name = []
lista_subcategorias_cant_items = []

for categoria_id in list(categorias_all.keys()):
    dicc_info_particular = categorias_all[categoria_id]
    categoria_name = dicc_info_particular["name"]
    cant_items_totales = dicc_info_particular["total_items_in_this_category"]
    lista_categorias_padre = dicc_info_particular['path_from_root']
    categoria_principal_id = lista_categorias_padre[0]["id"]
    if categoria_principal_id == "MLA1051" and len(lista_categorias_padre) > 1:
        lista_subcategorias_id.append(categoria_id)
        lista_subcategorias_name.append(categoria_name)
        lista_subcategorias_cant_items.append(cant_items_totales)

df_info_subcategorias = pd.DataFrame({"id": lista_subcategorias_id, "nombre":lista_subcategorias_name, 
              "cant_items":lista_subcategorias_cant_items})

# %%
df_info_subcategorias.sort_values("cant_items", ascending = False)
# Out:
#             id                          nombre  cant_items
# 9      MLA3502       Accesorios para Celulares      204700
# 37   MLA432437  Carcasas, Fundas y Protectores      140316
# 103    MLA5337           Fundas para Celulares      104235
# 7      MLA3813          Repuestos de Celulares       54556
# 0      MLA1055         Celulares y Smartphones       47157
# 105   MLA47540         Protectores de Pantalla       30985
# 45     MLA3517                      Cargadores       18946
# 31    MLA10675                  Displays y LCD       18732
# 8      MLA1053    Telefonía Fija e Inalámbrica       13395
# 106  MLA429749            Cargadores con Cable       13000
# 23     MLA3514                        Baterías       10492
# 2      MLA1058       Handies y Radiofrecuencia        8661
# 30     MLA5338                 Cables de Datos        8152
# 46   MLA432435            Colgantes y Soportes        7512
# 34    MLA10617                            Flex        6947
# 4    MLA417704       Smartwatches y Accesorios        6410
# 51    MLA61294                  Pines de Carga        5658
# 66   MLA429731                       Teléfonos        5258
# 115   MLA70411             Soportes para Autos        4564
# 102    MLA4656                        Carcasas        4419
# 26     MLA2910                      Accesorios        4310
# 25     MLA7039                Cámaras Internas        4166
# 83     MLA3529                           Otros        4022
# 20     MLA3518      Auriculares y Manos Libres        4014
# 44   MLA352679                      Smartwatch        3936
# 70     MLA5549                 Otros Repuestos        3883
# 75     MLA9467                        Memorias        3319
# 112  MLA407977                      Portátiles        3318
# 54     MLA2898                      Accesorios        3251
# 60     MLA1052           Centrales Telefónicas        2599
# ..         ...                             ...         ...
# 81     MLA5821                        Software         126
# 87    MLA57682   Amplificadores y Transmisores         122
# 56     MLA3253                   Contestadores         120
# 71    MLA10182            Lectores de Memorias         120
# 32   MLA417755                      Cargadores         115
# 97   MLA417048                          Fundas         104
# 3     MLA10616           Tarifadores y Cabinas          94
# 82   MLA417675     Ventiladores para Celulares          84
# 17     MLA5336                         Antenas          77
# 91   MLA436012                           Otros          71
# 118  MLA432439                           Otros          71
# 49     MLA3688                       Caller ID          69
# 78   MLA417773      Receptores Inalámbricos Qi          66
# 132    MLA2902                           Otros          65
# 85   MLA416945                          De SIM          60
# 36    MLA53597                     Tarifadores          45
# 79   MLA431967         Separadores de Displays          42
# 129  MLA432444                           Otros          41
# 67    MLA32075          Trackballs y Joysticks          36
# 33    MLA66807                         Cabinas          35
# 135  MLA432450                           Otros          34
# 73   MLA416203             Mantas Antiestática          27
# 84   MLA436014                       Bluetooth          24
# 77   MLA432995        Pines Extractores de Sim          21
# 48   MLA431968             Cortadores de Chips          19
# 42    MLA53603                           Otros          16
# 99    MLA70453                        Válvulas          15
# 117  MLA431100        Bloqueadores de Llamadas          10
# 21    MLA10183                        Bisagras           8
# 86   MLA436013                     Infrarrojos           0
#
# [136 rows x 3 columns]

# %%
print("Hay un total de", len(df_info_subcategorias), "subcategorías 'hoja' de la categoría 'Celulares y Teléfonos'.")
# Out:
# Hay un total de 136 subcategorías 'hoja' de la categoría 'Celulares y Teléfonos'.

# %% [markdown]
# #### Recolectamos los datos usando la API

# %%
t_inicial = time.perf_counter()

lista_dfs = []
for numero_categoria, categoria_id in enumerate(lista_subcategorias_id):
    categoria_name = lista_subcategorias_name[numero_categoria]
    cant_items_totales = lista_subcategorias_cant_items[numero_categoria]
    print("Recolectando data de la categoría:", str(numero_categoria), "de", len(lista_subcategorias_id)-1, "(categoría", categoria_name, ").")
    limite_for = min(20, int(np.floor(cant_items_totales / 50)))
    for pagina in range(limite_for):
        print("Página:" + str(pagina) + " de 19.", end='\r', flush=True)
        #categoria_id = categoria["id"]
        #categoria_name = categoria["name"]
        offset = str(50 * pagina + 1)      
        try:
            items = request_a_diccionario("https://api.mercadolibre.com/sites/MLA/search?category=" + categoria_id + "&limit=50&offset=" + offset)
            df = generar_df(items)
            lista_dfs.append(df)
            time.sleep(1)
        except Exception as err:
            print("Hubo un error en la llamada de la página", pagina)
    elapsed_time = time.perf_counter() - t_inicial
    print("Tiempo parcial de ejecución:", round(elapsed_time / 60, 2), "minutos.")
    print("-"*100)
        
elapsed_time = time.perf_counter() - t_inicial

print("Tiempo total de ejecución:", round(elapsed_time / 60, 2), "minutos.")
# Out:
# Recolectando data de la categoría: 0 de 136 (categoría Celulares y Smartphones ).
# Tiempo parcial de ejecución: 0.62 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 1 de 136 (categoría Lentes de Realidad Virtual ).
# Tiempo parcial de ejecución: 1.15 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 2 de 136 (categoría Handies y Radiofrecuencia ).
# Tiempo parcial de ejecución: 1.63 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 3 de 136 (categoría Tarifadores y Cabinas ).
# Tiempo parcial de ejecución: 1.66 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 4 de 136 (categoría Smartwatches y Accesorios ).
# Tiempo parcial de ejecución: 2.2 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 5 de 136 (categoría Telefonía IP ).
# Tiempo parcial de ejecución: 2.7 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 6 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 3.17 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 7 de 136 (categoría Repuestos de Celulares ).
# Tiempo parcial de ejecución: 3.72 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 8 de 136 (categoría Telefonía Fija e Inalámbrica ).
# Tiempo parcial de ejecución: 4.28 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 9 de 136 (categoría Accesorios para Celulares ).
# Tiempo parcial de ejecución: 4.89 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 10 de 136 (categoría Amplificadores de Señal ).
# Tiempo parcial de ejecución: 4.98 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 11 de 136 (categoría Equipos Base ).
# Tiempo parcial de ejecución: 5.43 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 12 de 136 (categoría Antenas ).
# Tiempo parcial de ejecución: 5.61 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 13 de 136 (categoría Equipos Móviles ).
# Tiempo parcial de ejecución: 5.75 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 14 de 136 (categoría Anillos para Celulares ).
# Tiempo parcial de ejecución: 6.1 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 15 de 136 (categoría Bandejas Porta Sim ).
# Tiempo parcial de ejecución: 6.57 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 16 de 136 (categoría Adaptadores ).
# Tiempo parcial de ejecución: 7.04 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 17 de 136 (categoría Antenas ).
# Tiempo parcial de ejecución: 7.07 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 18 de 136 (categoría Handies ).
# Tiempo parcial de ejecución: 7.58 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 19 de 136 (categoría Baterías ).
# Tiempo parcial de ejecución: 8.1 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 20 de 136 (categoría Auriculares y Manos Libres ).
# Tiempo parcial de ejecución: 8.64 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 21 de 136 (categoría Bisagras ).
# Tiempo parcial de ejecución: 8.64 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 22 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 9.03 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 23 de 136 (categoría Baterías ).
# Tiempo parcial de ejecución: 9.56 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 24 de 136 (categoría Botones ).
# Tiempo parcial de ejecución: 9.72 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 25 de 136 (categoría Cámaras Internas ).
# Tiempo parcial de ejecución: 10.2 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 26 de 136 (categoría Accesorios ).
# Tiempo parcial de ejecución: 10.69 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 27 de 136 (categoría Cables de Audio y Video ).
# Tiempo parcial de ejecución: 10.81 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 28 de 136 (categoría Carcasas ).
# Tiempo parcial de ejecución: 11.35 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 29 de 136 (categoría Baterías ).
# Tiempo parcial de ejecución: 11.44 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 30 de 136 (categoría Cables de Datos ).
# Tiempo parcial de ejecución: 11.92 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 31 de 136 (categoría Displays y LCD ).
# Tiempo parcial de ejecución: 12.43 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 32 de 136 (categoría Cargadores ).
# Tiempo parcial de ejecución: 12.48 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 33 de 136 (categoría Cabinas ).
# Tiempo parcial de ejecución: 12.48 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 34 de 136 (categoría Flex ).
# Tiempo parcial de ejecución: 12.95 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 35 de 136 (categoría Mallas ).
# Tiempo parcial de ejecución: 13.42 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 36 de 136 (categoría Tarifadores ).
# Tiempo parcial de ejecución: 13.42 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 37 de 136 (categoría Carcasas, Fundas y Protectores ).
# Tiempo parcial de ejecución: 13.98 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 38 de 136 (categoría Kit de Reparación de Celulares ).
# Tiempo parcial de ejecución: 14.23 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 39 de 136 (categoría Chips GSM ).
# Tiempo parcial de ejecución: 14.72 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 40 de 136 (categoría Protectores de Pantalla ).
# Tiempo parcial de ejecución: 14.91 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 41 de 136 (categoría Lentes ).
# Tiempo parcial de ejecución: 15.38 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 42 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 15.38 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 43 de 136 (categoría Micrófonos ).
# Tiempo parcial de ejecución: 15.59 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 44 de 136 (categoría Smartwatch ).
# Tiempo parcial de ejecución: 16.13 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 45 de 136 (categoría Cargadores ).
# Tiempo parcial de ejecución: 16.7 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 46 de 136 (categoría Colgantes y Soportes ).
# Tiempo parcial de ejecución: 17.22 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 47 de 136 (categoría Parlantes Internos ).
# Tiempo parcial de ejecución: 17.69 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 48 de 136 (categoría Cortadores de Chips ).
# Tiempo parcial de ejecución: 17.69 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 49 de 136 (categoría Caller ID ).
# Tiempo parcial de ejecución: 17.72 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 50 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 17.79 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 51 de 136 (categoría Pines de Carga ).
# Tiempo parcial de ejecución: 18.27 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 52 de 136 (categoría Gateways ).
# Tiempo parcial de ejecución: 18.44 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 53 de 136 (categoría Placas de Carga ).
# Tiempo parcial de ejecución: 18.9 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 54 de 136 (categoría Accesorios ).
# Tiempo parcial de ejecución: 19.37 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 55 de 136 (categoría Planes ).
# Tiempo parcial de ejecución: 19.53 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 56 de 136 (categoría Contestadores ).
# Tiempo parcial de ejecución: 19.57 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 57 de 136 (categoría Placas Madre ).
# Tiempo parcial de ejecución: 20.04 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 58 de 136 (categoría Gatillos Joystick ).
# Tiempo parcial de ejecución: 20.14 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 59 de 136 (categoría Routers ).
# Tiempo parcial de ejecución: 20.41 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 60 de 136 (categoría Centrales Telefónicas ).
# Tiempo parcial de ejecución: 20.91 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 61 de 136 (categoría Fotografía para Celulares ).
# Tiempo parcial de ejecución: 21.31 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 62 de 136 (categoría Teclados ).
# Tiempo parcial de ejecución: 21.4 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 63 de 136 (categoría Impresoras para Celulares ).
# Tiempo parcial de ejecución: 21.49 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 64 de 136 (categoría Teléfonos ).
# Tiempo parcial de ejecución: 21.93 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 65 de 136 (categoría Fax ).
# Tiempo parcial de ejecución: 22.45 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 66 de 136 (categoría Teléfonos ).
# Tiempo parcial de ejecución: 23.0 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 67 de 136 (categoría Trackballs y Joysticks ).
# Tiempo parcial de ejecución: 23.0 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 68 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 23.16 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 69 de 136 (categoría Lápices Ópticos ).
# Tiempo parcial de ejecución: 23.26 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 70 de 136 (categoría Otros Repuestos ).
# Tiempo parcial de ejecución: 23.73 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 71 de 136 (categoría Lectores de Memorias ).
# Tiempo parcial de ejecución: 23.78 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 72 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 23.89 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 73 de 136 (categoría Mantas Antiestática ).
# Tiempo parcial de ejecución: 23.89 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 74 de 136 (categoría Teléfonos Headset ).
# Tiempo parcial de ejecución: 24.14 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 75 de 136 (categoría Memorias ).
# Tiempo parcial de ejecución: 24.7 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 76 de 136 (categoría Parlantes Externos ).
# Tiempo parcial de ejecución: 24.8 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 77 de 136 (categoría Pines Extractores de Sim ).
# Tiempo parcial de ejecución: 24.8 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 78 de 136 (categoría Receptores Inalámbricos Qi ).
# Tiempo parcial de ejecución: 24.82 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 79 de 136 (categoría Separadores de Displays ).
# Tiempo parcial de ejecución: 24.82 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 80 de 136 (categoría Skins ).
# Tiempo parcial de ejecución: 24.96 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 81 de 136 (categoría Software ).
# Tiempo parcial de ejecución: 25.0 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 82 de 136 (categoría Ventiladores para Celulares ).
# Tiempo parcial de ejecución: 25.03 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 83 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 25.5 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 84 de 136 (categoría Bluetooth ).
# Tiempo parcial de ejecución: 25.5 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 85 de 136 (categoría De SIM ).
# Tiempo parcial de ejecución: 25.53 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 86 de 136 (categoría Infrarrojos ).
# Tiempo parcial de ejecución: 25.53 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 87 de 136 (categoría Amplificadores y Transmisores ).
# Tiempo parcial de ejecución: 25.57 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 88 de 136 (categoría Para Auriculares ).
# Tiempo parcial de ejecución: 25.82 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 89 de 136 (categoría USB ).
# Tiempo parcial de ejecución: 26.29 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 90 de 136 (categoría Auriculares ).
# Tiempo parcial de ejecución: 26.36 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 91 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 26.38 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 92 de 136 (categoría Baterías ).
# Tiempo parcial de ejecución: 26.55 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 93 de 136 (categoría Cables y Conectores ).
# Tiempo parcial de ejecución: 26.89 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 94 de 136 (categoría Antenas ).
# Tiempo parcial de ejecución: 27.28 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 95 de 136 (categoría Cargadores ).
# Tiempo parcial de ejecución: 27.34 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 96 de 136 (categoría Fuentes ).
# Tiempo parcial de ejecución: 27.46 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 97 de 136 (categoría Fundas ).
# Tiempo parcial de ejecución: 27.5 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 98 de 136 (categoría Micrófonos ).
# Tiempo parcial de ejecución: 27.72 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 99 de 136 (categoría Válvulas ).
# Tiempo parcial de ejecución: 27.72 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 100 de 136 (categoría Wattímetros / Roímetros ).
# Tiempo parcial de ejecución: 27.76 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 101 de 136 (categoría Otros Accesorios ).
# Tiempo parcial de ejecución: 28.15 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 102 de 136 (categoría Carcasas ).
# Tiempo parcial de ejecución: 28.68 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 103 de 136 (categoría Fundas para Celulares ).
# Tiempo parcial de ejecución: 29.22 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 104 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 29.37 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 105 de 136 (categoría Protectores de Pantalla ).
# Tiempo parcial de ejecución: 29.85 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 106 de 136 (categoría Cargadores con Cable ).
# Tiempo parcial de ejecución: 30.41 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 107 de 136 (categoría Protectores para Lentes ).
# Tiempo parcial de ejecución: 30.56 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 108 de 136 (categoría Fundas Cargadoras ).
# Tiempo parcial de ejecución: 30.88 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 109 de 136 (categoría Apoya Celulares ).
# Hubo un error en la llamada de la página 18
# Tiempo parcial de ejecución: 31.34 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 110 de 136 (categoría Inalámbricos ).
# Hubo un error en la llamada de la página 13
# Tiempo parcial de ejecución: 31.77 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 111 de 136 (categoría Colgantes y Correas ).
# Tiempo parcial de ejecución: 31.86 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 112 de 136 (categoría Portátiles ).
# Tiempo parcial de ejecución: 32.4 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 113 de 136 (categoría Porta Celulares ).
# Tiempo parcial de ejecución: 32.88 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 114 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 33.35 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 115 de 136 (categoría Soportes para Autos ).
# Tiempo parcial de ejecución: 33.84 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 116 de 136 (categoría Baterías ).
# Tiempo parcial de ejecución: 34.3 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 117 de 136 (categoría Bloqueadores de Llamadas ).
# Tiempo parcial de ejecución: 34.3 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 118 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 34.33 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 119 de 136 (categoría Cables Telefónicos ).
# Tiempo parcial de ejecución: 34.75 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 120 de 136 (categoría Filtros Telefónicos ).
# Tiempo parcial de ejecución: 34.84 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 121 de 136 (categoría Accesorios ).
# Tiempo parcial de ejecución: 34.93 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 122 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 35.12 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 123 de 136 (categoría Cámaras Externas ).
# Tiempo parcial de ejecución: 35.39 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 124 de 136 (categoría Equipos ).
# Tiempo parcial de ejecución: 35.87 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 125 de 136 (categoría Placas ).
# Tiempo parcial de ejecución: 36.2 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 126 de 136 (categoría Flash para Celulares ).
# Tiempo parcial de ejecución: 36.32 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 127 de 136 (categoría Teléfonos y Consolas ).
# Tiempo parcial de ejecución: 36.47 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 128 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 36.57 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 129 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 36.57 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 130 de 136 (categoría Aparatos ).
# Tiempo parcial de ejecución: 37.06 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 131 de 136 (categoría Repuestos ).
# Tiempo parcial de ejecución: 37.15 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 132 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 37.18 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 133 de 136 (categoría Antenas para Radio-Bases ).
# Tiempo parcial de ejecución: 37.47 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 134 de 136 (categoría Antenas para Walkie-Talkies ).
# Tiempo parcial de ejecución: 37.57 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 135 de 136 (categoría Otros ).
# Tiempo parcial de ejecución: 37.57 minutos.
# ----------------------------------------------------------------------------------------------------
# Tiempo total de ejecución: 37.57 minutos.

# %% [markdown]
# #### Juntamos todo en un sólo dataframe

# %%
df_total_original = pd.concat(lista_dfs, axis = 0)

# %% [markdown]
# #### Corroboramos el tamaño del dataset obtenido

# %%
print("Tamaño total:", len(df_total_original))
# Out:
# Tamaño total: 75313

# %% [markdown]
# #### Eliminamos duplicados

# %%
subset_columnas = list(df_total_original.columns)
subset_columnas.remove("tags")
print("Cantidad de duplicados:", df_total_original.duplicated(keep="first", subset = subset_columnas).sum())
df_total_original = df_total_original[~df_total_original.duplicated(keep="first", subset = subset_columnas)]
print("Eliminamos los duplicados.")
print("Quedaron", len(df_total_original), "registros en total.")
# Out:
# Cantidad de duplicados: 17367
# Eliminamos los duplicados.
# Quedaron 57946 registros en total.

# %% [markdown]
# #### Guardamos en un csv

# %%
df_total_original.to_csv("df_total_original.csv", index = False)

# %%
df_total_original.head(2)
# Out:
#              id site_id                                    title    price  \
# 0  MLA856785349     MLA   Moto E6 Play 32 Gb Ocean Blue 2 Gb Ram  19990.0
# 1  MLA845554053     MLA  Moto G8 Play 32 Gb Knight Gray 2 Gb Ram  25999.0
#
#   currency_id  available_quantity  sold_quantity buying_mode listing_type_id  \
# 0         ARS                50.0            5.0  buy_it_now    gold_special
# 1         ARS                 1.0          200.0  buy_it_now    gold_special
#
#   condition                        ...                          category_id  \
# 0       new                        ...                              MLA1055
# 1       new                        ...                              MLA1055
#
#   official_store_id catalog_product_id  attributes__marca  attributes__modelo  \
# 0               NaN        MLA15243582           Motorola             E6 Play
# 1               NaN        MLA15273696           Motorola             G8 Play
#
#   seller__power_seller_status seller__car_dealer  \
# 0                      silver                0.0
# 1                    platinum                0.0
#
#   seller__eshop__eshop_experience seller__eshop__eshop_id  \
# 0                             NaN                     NaN
# 1                               0                  162995
#
#                                                 tags
# 0  [loyalty_discount_eligible, brand_verified, ex...
# 1  [brand_verified, extended_warranty_eligible, g...
#
# [2 rows x 26 columns]
