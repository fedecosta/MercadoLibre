# %% [markdown]
# # Objetivos

# %% [markdown]
# El objetivo de este notebook es recolectar información para luego realizar un breve análisis sobre las publicaciones con descuentos en el site de MercadoLibre (esto se lleva a cabo en el notebook "analisis").
#
# La información se recolecta a través de las APIS publicas de MercadoLibre (https://developers.mercadolibre.com.ar/es_ar/api-docs-es).
#
# Es importante notar que se tomó en cuenta sólo el site de Argentina y se tomaron 1000 registros (publicaciones) por cada una de las categorías principales del site.
#
# Este notebook guarda toda la información recolectada en el csv "df_total_original.csv".

# %% [markdown]
# # Índice

# %% [markdown]
# * [1 - Imports](#1)
# * [2 - Recolección de datos](#2)

# %% [markdown]
# # 1 - Imports <a id="1"></a>

# %%
import numpy as np
import pandas as pd

import time
from time import process_time

from funciones import request_a_diccionario, generar_df

# %% [markdown]
# # 2 - Recolección de datos <a id="2"></a>

# %% [markdown]
# #### Analizamos los países que hay

# %%
lista_paises = request_a_diccionario("https://api.mercadolibre.com/sites")

# %%
lista_paises
# Out:
# [{'default_currency_id': 'MXN', 'id': 'MLM', 'name': 'Mexico'},
#  {'default_currency_id': 'BOB', 'id': 'MBO', 'name': 'Bolivia'},
#  {'default_currency_id': 'CUP', 'id': 'MCU', 'name': 'Cuba'},
#  {'default_currency_id': 'USD', 'id': 'MEC', 'name': 'Ecuador'},
#  {'default_currency_id': 'USD', 'id': 'MSV', 'name': 'El Salvador'},
#  {'default_currency_id': 'NIO', 'id': 'MNI', 'name': 'Nicaragua'},
#  {'default_currency_id': 'HNL', 'id': 'MHN', 'name': 'Honduras'},
#  {'default_currency_id': 'PAB', 'id': 'MPA', 'name': 'Panamá'},
#  {'default_currency_id': 'PEN', 'id': 'MPE', 'name': 'Perú'},
#  {'default_currency_id': 'GTQ', 'id': 'MGT', 'name': 'Guatemala'},
#  {'default_currency_id': 'CRC', 'id': 'MCR', 'name': 'Costa Rica'},
#  {'default_currency_id': 'DOP', 'id': 'MRD', 'name': 'Dominicana'},
#  {'default_currency_id': 'VES', 'id': 'MLV', 'name': 'Venezuela'},
#  {'default_currency_id': 'COP', 'id': 'MCO', 'name': 'Colombia'},
#  {'default_currency_id': 'BRL', 'id': 'MLB', 'name': 'Brasil'},
#  {'default_currency_id': 'UYU', 'id': 'MLU', 'name': 'Uruguay'},
#  {'default_currency_id': 'CLP', 'id': 'MLC', 'name': 'Chile'},
#  {'default_currency_id': 'ARS', 'id': 'MLA', 'name': 'Argentina'},
#  {'default_currency_id': 'PYG', 'id': 'MPY', 'name': 'Paraguay'}]

# %% [markdown]
# #### Analizamos las categorías que hay

# %%
lista_categorias = request_a_diccionario("https://api.mercadolibre.com/sites/MLA/categories")

# %%
print("Hay un total de", len(lista_categorias), "categorías.")
# Out:
# Hay un total de 31 categorías.

# %%
lista_categorias
# Out:
# [{'id': 'MLA5725', 'name': 'Accesorios para Vehículos'},
#  {'id': 'MLA1512', 'name': 'Agro'},
#  {'id': 'MLA1403', 'name': 'Alimentos y Bebidas'},
#  {'id': 'MLA1071', 'name': 'Animales y Mascotas'},
#  {'id': 'MLA1367', 'name': 'Antigüedades y Colecciones'},
#  {'id': 'MLA1368', 'name': 'Arte, Librería y Mercería'},
#  {'id': 'MLA1743', 'name': 'Autos, Motos y Otros'},
#  {'id': 'MLA1384', 'name': 'Bebés'},
#  {'id': 'MLA1246', 'name': 'Belleza y Cuidado Personal'},
#  {'id': 'MLA1039', 'name': 'Cámaras y Accesorios'},
#  {'id': 'MLA1051', 'name': 'Celulares y Teléfonos'},
#  {'id': 'MLA1648', 'name': 'Computación'},
#  {'id': 'MLA1144', 'name': 'Consolas y Videojuegos'},
#  {'id': 'MLA1276', 'name': 'Deportes y Fitness'},
#  {'id': 'MLA5726', 'name': 'Electrodomésticos y Aires Ac.'},
#  {'id': 'MLA1000', 'name': 'Electrónica, Audio y Video'},
#  {'id': 'MLA2547', 'name': 'Entradas para Eventos'},
#  {'id': 'MLA407134', 'name': 'Herramientas y Construcción'},
#  {'id': 'MLA1574', 'name': 'Hogar, Muebles y Jardín'},
#  {'id': 'MLA1499', 'name': 'Industrias y Oficinas'},
#  {'id': 'MLA1459', 'name': 'Inmuebles'},
#  {'id': 'MLA1182', 'name': 'Instrumentos Musicales'},
#  {'id': 'MLA3937', 'name': 'Joyas y Relojes'},
#  {'id': 'MLA1132', 'name': 'Juegos y Juguetes'},
#  {'id': 'MLA3025', 'name': 'Libros, Revistas y Comics'},
#  {'id': 'MLA1168', 'name': 'Música, Películas y Series'},
#  {'id': 'MLA1430', 'name': 'Ropa y Accesorios'},
#  {'id': 'MLA409431', 'name': 'Salud y Equipamiento Médico'},
#  {'id': 'MLA1540', 'name': 'Servicios'},
#  {'id': 'MLA9304', 'name': 'Souvenirs, Cotillón y Fiestas'},
#  {'id': 'MLA1953', 'name': 'Otras categorías'}]

# %% [markdown]
# #### Analizamos las subcategorías que hay

# %%
dicc_subcategorias = {}
for categoria in lista_categorias:
    categoria_id = categoria["id"]
    categoria_name = categoria["name"]
    info = request_a_diccionario("https://api.mercadolibre.com/categories/" + categoria_id)
    print("-"*100)
    print("Categoría:", categoria_name)
    children_categories = info["children_categories"]
    print("Cantidad de subcategorías:", len(children_categories))
    for subcategoria in children_categories:
        dicc_subcategorias[subcategoria["id"]] = subcategoria["name"]
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Categoría: Accesorios para Vehículos
# Cantidad de subcategorías: 19
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Agro
# Cantidad de subcategorías: 8
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Alimentos y Bebidas
# Cantidad de subcategorías: 5
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Animales y Mascotas
# Cantidad de subcategorías: 10
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Antigüedades y Colecciones
# Cantidad de subcategorías: 8
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Arte, Librería y Mercería
# Cantidad de subcategorías: 8
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Autos, Motos y Otros
# Cantidad de subcategorías: 13
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Bebés
# Cantidad de subcategorías: 15
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Belleza y Cuidado Personal
# Cantidad de subcategorías: 14
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Cámaras y Accesorios
# Cantidad de subcategorías: 11
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Celulares y Teléfonos
# Cantidad de subcategorías: 10
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Computación
# Cantidad de subcategorías: 20
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Consolas y Videojuegos
# Cantidad de subcategorías: 6
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Deportes y Fitness
# Cantidad de subcategorías: 40
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Electrodomésticos y Aires Ac.
# Cantidad de subcategorías: 9
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Electrónica, Audio y Video
# Cantidad de subcategorías: 15
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Entradas para Eventos
# Cantidad de subcategorías: 6
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Herramientas y Construcción
# Cantidad de subcategorías: 10
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Hogar, Muebles y Jardín
# Cantidad de subcategorías: 13
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Industrias y Oficinas
# Cantidad de subcategorías: 12
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Inmuebles
# Cantidad de subcategorías: 16
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Instrumentos Musicales
# Cantidad de subcategorías: 12
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Joyas y Relojes
# Cantidad de subcategorías: 11
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Juegos y Juguetes
# Cantidad de subcategorías: 26
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Libros, Revistas y Comics
# Cantidad de subcategorías: 6
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Música, Películas y Series
# Cantidad de subcategorías: 4
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Ropa y Accesorios
# Cantidad de subcategorías: 24
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Salud y Equipamiento Médico
# Cantidad de subcategorías: 8
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Servicios
# Cantidad de subcategorías: 18
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Souvenirs, Cotillón y Fiestas
# Cantidad de subcategorías: 10
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Categoría: Otras categorías
# Cantidad de subcategorías: 12
# ----------------------------------------------------------------------------------------------------

# %%
print("Hay un total de", len(dicc_subcategorias), "subcategorías.")
# Out:
# Hay un total de 399 subcategorías.

# %%
dicc_subcategorias
# Out:
# {'MLA4711': 'Acc. para Motos y Cuatriciclos',
#  'MLA417044': 'Acc. y Repuestos Náuticos',
#  'MLA86360': 'Acc. y Repuestos para Camiones',
#  'MLA6520': 'Accesorios de Auto y Camioneta',
#  'MLA3381': 'Audio para Vehículos',
#  'MLA4610': 'GNC',
#  'MLA2227': 'Herramientas',
#  'MLA86838': 'Limpieza de Vehículos',
#  'MLA6537': 'Llantas',
#  'MLA8531': 'Navegadores GPS',
#  'MLA400928': 'Neumáticos',
#  'MLA402999': 'Performance',
#  'MLA1747': 'Repuestos Autos y Camionetas',
#  'MLA419936': 'Repuestos de Maquinaria Pesada',
#  'MLA1771': 'Repuestos Motos y Cuatriciclos',
#  'MLA86080': 'Seguridad Vehicular',
#  'MLA377674': 'Service Programado',
#  'MLA4589': 'Tuning',
#  'MLA6177': 'Otros',
#  'MLA442345': 'Alimentación y Suplementos',
#  'MLA442346': 'Animales',
#  'MLA442344': 'Generadores de Energía',
#  'MLA442343': 'Insumos Agrícolas',
#  'MLA407816': 'Insumos Agroganaderos',
#  'MLA417282': 'Máquinas y Herramientas',
#  'MLA442351': 'Repuestos de Maquinaria Pesada',
#  'MLA404085': 'Otros',
#  'MLA178700': 'Bebidas',
#  'MLA1423': 'Comestibles',
#  'MLA410883': 'Comida Preparada y Catering',
#  'MLA194324': 'Frescos',
#  'MLA1417': 'Otros',
#  'MLA1100': 'Aves',
#  'MLA1117': 'Caballos',
#  'MLA6573': 'Conejos',
#  'MLA1081': 'Gatos',
#  'MLA429311': 'Insectos',
#  'MLA1091': 'Peces',
#  'MLA1072': 'Perros',
#  'MLA1111': 'Reptiles y Anfibios',
#  'MLA1105': 'Roedores',
#  'MLA1126': 'Otros',
#  'MLA436789': 'Antigüedades',
#  'MLA31770': 'Coleccionables de Deportes',
#  'MLA2662': 'Esculturas',
#  'MLA1861': 'Filatelia',
#  'MLA1805': 'Militaría y Afines',
#  'MLA1806': 'Monedas y Billetes',
#  'MLA3475': 'Posters',
#  'MLA1383': 'Otros',
#  'MLA34263': 'Arte',
#  'MLA381266': 'Espejos Venecitas',
#  'MLA436793': 'Insumos para Hacer Velas',
#  'MLA5982': 'Librería',
#  'MLA10934': 'Mercería',
#  'MLA432923': 'Moldes para Jabones',
#  'MLA437077': 'Piezas para Llaveros',
#  'MLA34294': 'Otros',
#  'MLA93412': 'Autos Chocados y Averiados',
#  'MLA1745': 'Autos de Colección',
#  'MLA1744': 'Autos y Camionetas',
#  'MLA58254': 'Camiones',
#  'MLA51547': 'Colectivos',
#  'MLA7312': 'Maquinaria Agrícola',
#  'MLA405183': 'Maquinaria Vial',
#  'MLA80579': 'Motorhomes',
#  'MLA1763': 'Motos',
#  'MLA1785': 'Náutica',
#  'MLA1784': 'Planes de Ahorro',
#  'MLA93430': 'Semirremolques',
#  'MLA1907': 'Otros Vehículos',
#  'MLA8814': 'Andadores y Vehículos de Bebés',
#  'MLA5702': 'Artículos de Bebés para Baño',
#  'MLA417864': 'Artículos de Maternidad',
#  'MLA417853': 'Chupetes y Mordillos',
#  'MLA417851': 'Comida para Bebés',
#  'MLA8322': 'Corralitos',
#  'MLA5362': 'Cuarto del Bebé',
#  'MLA409456': 'Higiene y Cuidado del Bebé',
#  'MLA1392': 'Juegos y Juguetes para Bebés',
#  'MLA5360': 'Lactancia y Alimentación',
#  'MLA418189': 'Paseo del Bebé',
#  'MLA1396': 'Ropa y Calzado para Bebés',
#  'MLA417887': 'Salud del Bebé',
#  'MLA1390': 'Seguridad para Bebés',
#  'MLA1889': 'Otros',
#  'MLA431642': 'Artículos de Peluquería',
#  'MLA417575': 'Barbería',
#  'MLA1253': 'Cuidado de la Piel',
#  'MLA1263': 'Cuidado del Cabello',
#  'MLA43673': 'Depilación',
#  'MLA409558': 'Electrodomésticos de Belleza',
#  'MLA431646': 'Farmacia',
#  'MLA393366': 'Higiene Personal',
#  'MLA29884': 'Manicuría y Pedicuría',
#  'MLA1248': 'Maquillaje',
#  'MLA1271': 'Perfumes',
#  'MLA391873': 'Splash Corporal',
#  'MLA417770': 'Tratamientos de Belleza',
#  'MLA1275': 'Otros',
#  'MLA1049': 'Accesorios para Cámaras',
#  'MLA9808': 'Álbumes y Portarretratos',
#  'MLA5849': 'Cables',
#  'MLA430361': 'Cámaras',
#  'MLA430403': 'Drones y Accesorios',
#  'MLA392132': 'Filmadoras y Cámaras de Acción',
#  'MLA4708': 'Instrumentos Ópticos',
#  'MLA59376': 'Lentes y Filtros',
#  'MLA430989': 'Repuestos para Cámaras',
#  'MLA10372': 'Revelado y Laboratorio',
#  'MLA1914': 'Otros',
#  'MLA3502': 'Accesorios para Celulares',
#  'MLA1055': 'Celulares y Smartphones',
#  'MLA1058': 'Handies y Radiofrecuencia',
#  'MLA401278': 'Lentes de Realidad Virtual',
#  'MLA3813': 'Repuestos de Celulares',
#  'MLA417704': 'Smartwatches y Accesorios',
#  'MLA10616': 'Tarifadores y Cabinas',
#  'MLA1053': 'Telefonía Fija e Inalámbrica',
#  'MLA5237': 'Telefonía IP',
#  'MLA1915': 'Otros',
#  'MLA416199': 'Accesorios de Antiestática',
#  'MLA430598': 'Almacenamiento',
#  'MLA430918': 'Cables y Hubs USB',
#  'MLA3699': 'Cajas, Sobres y Porta CDs',
#  'MLA3794': 'Componentes de PC',
#  'MLA1700': 'Conectividad y Redes',
#  'MLA1718': 'Estabilizadores y UPS',
#  'MLA2141': 'Impresión',
#  'MLA430687': 'Laptops y Accesorios',
#  'MLA1660': 'Lectores y Scanners',
#  'MLA36845': 'Limpieza y Cuidado de PCs',
#  'MLA1656': 'Monitores y Accesorios',
#  'MLA430630': 'Mouses, Teclados y Controles',
#  'MLA1651': 'Palms y Handhelds',
#  'MLA430637': 'PC de Escritorio',
#  'MLA5017': 'Proyectores y Pantallas',
#  'MLA1723': 'Software',
#  'MLA400950': 'Tablets y Accesorios',
#  'MLA430615': 'Webcams y Audio para PC',
#  'MLA1912': 'Otros',
#  'MLA438578': 'Accesorios para Consolas',
#  'MLA438566': 'Consolas',
#  'MLA8232': 'Flippers y Arcade',
#  'MLA438579': 'Repuestos para Consolas',
#  'MLA373840': 'Videojuegos',
#  'MLA438759': 'Otros',
#  'MLA2480': 'Artes Marciales y Boxeo',
#  'MLA416831': 'Bádminton',
#  'MLA1309': 'Básquet',
#  'MLA1279': 'Buceo',
#  'MLA1362': 'Camping, Caza y Pesca',
#  'MLA438233': 'Canoas, Kayaks e Inflables',
#  'MLA1292': 'Ciclismo',
#  'MLA1349': 'Equitación y Polo',
#  'MLA417504': 'Esgrima',
#  'MLA1297': 'Esqui y Snowboard',
#  'MLA1338': 'Fitness y Musculación',
#  'MLA1285': 'Fútbol',
#  'MLA1302': 'Fútbol Americano',
#  'MLA1342': 'Golf',
#  'MLA37856': 'Handball',
#  'MLA3732': 'Hockey',
#  'MLA4697': 'Juegos de Salón',
#  'MLA4682': 'Kitesurf',
#  'MLA410723': 'Monopatines y Scooters',
#  'MLA47786': 'Montañismo y Trekking',
#  'MLA1278': 'Natación',
#  'MLA4218': 'Paintball',
#  'MLA432691': 'Parapente',
#  'MLA1293': 'Patín, Gimnasia y Danza',
#  'MLA8959': 'Pilates y Yoga',
#  'MLA3723': 'Pulsómetros y Cronómetros',
#  'MLA417397': 'Ropa Deportiva',
#  'MLA3731': 'Rugby',
#  'MLA1295': 'Skateboard y Sandboard',
#  'MLA417742': 'Slackline',
#  'MLA18369': 'Softball y Beisbol',
#  'MLA438178': 'Suplementos y Shakers',
#  'MLA1281': 'Surf y Bodyboard',
#  'MLA1322': 'Tenis, Padel y Squash ',
#  'MLA440904': 'Tiro Deportivo',
#  'MLA1333': 'Voley',
#  'MLA1978': 'Wakeboard y Esqui Acuático',
#  'MLA1282': 'Windsurf',
#  'MLA3724': 'Zapatillas',
#  'MLA1358': 'Otros',
#  'MLA6355': 'Artefactos de Cuidado Personal',
#  'MLA385177': 'Climatización',
#  'MLA1618': 'Cocción',
#  'MLA117258': 'Dispensadores y Purificadores',
#  'MLA438282': 'Lavado',
#  'MLA438284': 'Pequeños Electrodomésticos',
#  'MLA1576': 'Refrigeración',
#  'MLA398570': 'Repuestos y Accesorios',
#  'MLA5977': 'Otros',
#  'MLA3690': 'Accesorios para Audio y Video',
#  'MLA431414': 'Accesorios para TV',
#  'MLA409810': 'Audio',
#  'MLA5054': 'Cables',
#  'MLA11830': 'Componentes Electrónicos',
#  'MLA4632': 'Controles Remotos',
#  'MLA352294': 'Drones y Accesorios',
#  'MLA58775': 'Fundas y Bolsos',
#  'MLA352001': 'Media Streaming',
#  'MLA4641': 'Pilas y Cargadores',
#  'MLA4800': 'Proyectores y Pantallas',
#  'MLA322074': 'Repuestos para TV',
#  'MLA1002': 'TVs',
#  'MLA1015': 'Video',
#  'MLA1070': 'Otros',
#  'MLA10512': 'Entradas de Colección',
#  'MLA10434': 'Eventos Deportivos',
#  'MLA407872': 'Exposiciones',
#  'MLA10405': 'Recitales',
#  'MLA10451': 'Teatro',
#  'MLA10513': 'Otras Entradas',
#  'MLA30088': 'Aberturas',
#  'MLA411920': 'Baños y Sanitarios',
#  'MLA1500': 'Construcción',
#  'MLA2467': 'Electricidad',
#  'MLA5226': 'Herramientas',
#  'MLA411938': 'Mobiliario para Cocinas',
#  'MLA403700': 'Pinturería',
#  'MLA14548': 'Pisos y Revestimientos',
#  'MLA435273': 'Plomería',
#  'MLA407135': 'Otros',
#  'MLA1631': 'Adornos y Decoración del Hogar',
#  'MLA1613': 'Baños',
#  'MLA1592': 'Bazar y Cocina',
#  'MLA1608': 'Colchones y Sommiers',
#  'MLA436140': 'Cortinas y Accesorios',
#  'MLA436069': 'Cuidado del Hogar y Lavandería',
#  'MLA1582': 'Iluminación para el Hogar',
#  'MLA1621': 'Jardines y Exteriores',
#  'MLA436380': 'Muebles para el Hogar',
#  'MLA436414': 'Organización para el Hogar',
#  'MLA4624': 'Seguridad para el Hogar',
#  'MLA436246': 'Textiles de Hogar y Decoración',
#  'MLA1902': 'Otros',
#  'MLA5284': 'Arquitectura y Diseño',
#  'MLA48904': 'Embalajes',
#  'MLA5343': 'Equipamiento Comercial',
#  'MLA413614': 'Equipamiento para Industrias',
#  'MLA2102': 'Equipamiento para Oficinas',
#  'MLA5182': 'Industria Gastronómica',
#  'MLA412676': 'Industria Gráfica e Impresión',
#  'MLA5160': 'Industria Textil',
#  'MLA5174': 'Material de Promoción',
#  'MLA5169': 'Seguridad Industrial',
#  'MLA12555': 'Uniformes',
#  'MLA1893': 'Otros',
#  'MLA374730': 'Camas Náuticas',
#  'MLA1496': 'Campos',
#  'MLA1466': 'Casas',
#  'MLA50541': 'Cocheras',
#  'MLA392265': 'Consultorios',
#  'MLA1472': 'Departamentos',
#  'MLA1475': 'Depósitos y Galpones',
#  'MLA50545': 'Fondo de Comercio',
#  'MLA79242': 'Locales',
#  'MLA50538': 'Oficinas',
#  'MLA50544': 'Parcelas, Nichos y Bóvedas',
#  'MLA105179': 'PH',
#  'MLA50547': 'Quintas',
#  'MLA1493': 'Terrenos y Lotes',
#  'MLA50536': 'Tiempo Compartido',
#  'MLA1892': 'Otros Inmuebles',
#  'MLA3024': 'Baterías y Percusión',
#  'MLA435173': 'Equipos de DJ y Accesorios',
#  'MLA434917': 'Estudio de Grabación',
#  'MLA4611': 'Instrumentos de Cuerdas',
#  'MLA3005': 'Instrumentos de Viento',
#  'MLA434818': 'Metrónomos',
#  'MLA434816': 'Micrófonos y Amplificadores',
#  'MLA434927': 'Parlantes y Bafles',
#  'MLA3360': 'Partituras y Letras',
#  'MLA434786': 'Pedales y Accesorios',
#  'MLA2100': 'Teclados y Pianos',
#  'MLA3014': 'Otros',
#  'MLA431676': 'Exhibidores y Joyeros',
#  'MLA404419': 'Insumos para Joyería',
#  'MLA1431': 'Joyas y Bijouterie',
#  'MLA431678': 'Piedras Preciosas',
#  'MLA437168': 'Piercings',
#  'MLA431891': 'Plumas y Lapiceras de Lujo',
#  'MLA6750': 'Pulsómetros y Cronómetros',
#  'MLA431677': 'Relojes',
#  'MLA417301': 'Repuestos para Relojes',
#  'MLA399230': 'Smartwatch',
#  'MLA3938': 'Otros',
#  'MLA352344': 'Armas y Lanzadores de Juguete',
#  'MLA1157': 'Bloques y Construcción',
#  'MLA433060': 'Casas y Carpas para Niños',
#  'MLA418284': 'Dibujo, Pintura y Manualidades',
#  'MLA2967': 'Electrónicos para Niños',
#  'MLA1831': 'Figuritas, Álbumes y Cromos',
#  'MLA432873': 'Hobbies',
#  'MLA11229': 'Instrumentos Musicales',
#  'MLA433069': 'Juegos de Agua y Playa',
#  'MLA432988': 'Juegos de Mesa y Cartas',
#  'MLA1167': 'Juegos de Plaza y Aire Libre',
#  'MLA4696': 'Juegos de Salón',
#  'MLA432991': 'Juguetes Antiestrés e Ingenio',
#  'MLA416865': 'Juguetes de Bromas',
#  'MLA432818': 'Juguetes de Oficios',
#  'MLA3655': 'Juguetes para Bebés',
#  'MLA37615': 'Mesas y Sillas para Niños',
#  'MLA432888': 'Muñecos y Muñecas',
#  'MLA12087': 'Patines y Patinetas',
#  'MLA94997': 'Pelotas y Animales Saltarines',
#  'MLA6558': 'Peloteros y Castillos',
#  'MLA1166': 'Peluches',
#  'MLA433047': 'Títeres y Marionetas',
#  'MLA432871': 'Vehículos de Juguete',
#  'MLA6151': 'Vehículos Montables para Niños',
#  'MLA1910': 'Otros',
#  'MLA433385': 'Catálogos',
#  'MLA3043': 'Comics e Historietas',
#  'MLA412445': 'Libros',
#  'MLA3044': 'Manga',
#  'MLA1955': 'Revistas',
#  'MLA1227': 'Otros',
#  'MLA1174': 'Música',
#  'MLA13508': 'Películas',
#  'MLA7841': 'Series de TV',
#  'MLA1228': 'Otros',
#  'MLA3114': 'Accesorios de Moda',
#  'MLA109276': 'Bermudas y Shorts',
#  'MLA417226': 'Blusas',
#  'MLA109085': 'Buzos y Hoodies',
#  'MLA109026': 'Calzado',
#  'MLA95955': 'Calzas',
#  'MLA417218': 'Camisas',
#  'MLA109096': 'Camperas, Tapados y Trenchs',
#  'MLA109254': 'Enteritos',
#  'MLA110761': 'Equipaje, Bolsos y Carteras',
#  'MLA413460': 'Lotes de Ropa',
#  'MLA109282': 'Pantalones, Jeans y Joggings',
#  'MLA373771': 'Polleras',
#  'MLA109042': 'Remeras, Musculosas y Chombas',
#  'MLA417479': 'Ropa de Danza y Patinaje',
#  'MLA6839': 'Ropa Deportiva',
#  'MLA109278': 'Ropa Interior y de Dormir',
#  'MLA1455': 'Ropa y Calzado para Bebés',
#  'MLA109081': 'Saquitos, Sweaters y Chalecos',
#  'MLA109089': 'Trajes',
#  'MLA109270': 'Trajes de Baño',
#  'MLA12554': 'Uniformes y Ropa de Trabajo',
#  'MLA373770': 'Vestidos',
#  'MLA1911': 'Otros',
#  'MLA5395': 'Cuidado de la Salud',
#  'MLA6556': 'Equipamiento Médico',
#  'MLA29912': 'Masajes',
#  'MLA435066': 'Movilidad',
#  'MLA401562': 'Ortopedia',
#  'MLA8830': 'Suplementos Alimenticios',
#  'MLA43719': 'Terapias Alternativas',
#  'MLA409463': 'Otros',
#  'MLA414050': 'Asesoramiento Contable y Legal',
#  'MLA10514': 'Belleza y Cuidado Personal',
#  'MLA414051': 'Comunicación y diseño',
#  'MLA43986': 'Cursos y Clases',
#  'MLA91058': 'Delivery',
#  'MLA1550': 'Fiestas y Eventos',
#  'MLA122264': 'Fotografía, Música y Cine',
#  'MLA122258': 'Hogar y Construcción',
#  'MLA56666': 'Imprenta',
#  'MLA9007': 'Mantenimiento de Vehículos',
#  'MLA111029': 'Medicina y Salud',
#  'MLA91088': 'Ropa y Moda',
#  'MLA11798': 'Servicios para Mascotas',
#  'MLA91083': 'Servicios para Oficinas',
#  'MLA122201': 'Tecnología',
#  'MLA9038': 'Transporte',
#  'MLA1229': 'Viajes y Turismo',
#  'MLA1898': 'Otros Servicios',
#  'MLA24673': 'Cotillón',
#  'MLA403648': 'Decoración para Fiestas',
#  'MLA413646': 'Descartables para Fiestas',
#  'MLA24790': 'Disfraces',
#  'MLA435284': 'Espuma, Serpentina y Confeti',
#  'MLA412184': 'Invitaciones y Tarjetas',
#  'MLA100778': 'Kits Imprimibles para Fiestas',
#  'MLA412009': 'Props para Photo Booths',
#  'MLA10056': 'Souvenirs',
#  'MLA24693': 'Otros',
#  'MLA2818': 'Adultos',
#  'MLA2335': 'Cigarrillos y Afines',
#  'MLA406028': 'Coberturas Extendidas',
#  'MLA417785': 'Criptomonedas',
#  'MLA1740': 'Esoterismo',
#  'MLA401316': 'Gift Cards',
#  'MLA73672': 'Insumos para Tatuajes',
#  'MLA433536': 'Kits de Criminalística',
#  'MLA433022': 'Licencias para Taxis',
#  'MLA413190': 'Mangas de Viento',
#  'MLA421364': 'Pirotecnia',
#  'MLA3530': 'Otros'}

# %% [markdown]
# #### Recolectamos los datos usando la API

# %% [markdown]
# ### NOTA: vamos a hacer el análisis sólo para Argentina

# %%
t_inicial = time.perf_counter()

lista_dfs = []
for numero_categoria, categoria in enumerate(lista_categorias):
    print("Recolectando data de la categoría:", str(numero_categoria), "de", len(lista_categorias), "(categoría", categoria["name"], ").")
    for pagina in range(20):
        print("Página:" + str(pagina) + " de 19.", end='\r', flush=True)
        categoria_id = categoria["id"]
        categoria_name = categoria["name"]
        offset = str(50 * pagina + 1)
        items = request_a_diccionario("https://api.mercadolibre.com/sites/MLA/search?category=" + categoria_id + "&limit=50&offset=" + offset)
        df = generar_df(items)
        df["categoria_principal"] = categoria_name
        lista_dfs.append(df)
        time.sleep(1)
    elapsed_time = time.perf_counter() - t_inicial
    print("Tiempo de ejecución:", round(elapsed_time / 60, 2), "minutos.")
    print("-"*100)
        
elapsed_time = time.perf_counter() - t_inicial

print("Tiempo total de ejecución:", round(elapsed_time / 60, 2), "minutos.")
# Out:
# Recolectando data de la categoría: 0 de 31 (categoría Accesorios para Vehículos ).
# Tiempo de ejecución: 1.06 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 1 de 31 (categoría Agro ).
# Tiempo de ejecución: 1.65 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 2 de 31 (categoría Alimentos y Bebidas ).
# Tiempo de ejecución: 2.22 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 3 de 31 (categoría Animales y Mascotas ).
# Tiempo de ejecución: 2.84 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 4 de 31 (categoría Antigüedades y Colecciones ).
# Tiempo de ejecución: 3.47 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 5 de 31 (categoría Arte, Librería y Mercería ).
# Tiempo de ejecución: 4.09 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 6 de 31 (categoría Autos, Motos y Otros ).
# Tiempo de ejecución: 4.76 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 7 de 31 (categoría Bebés ).
# Tiempo de ejecución: 5.43 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 8 de 31 (categoría Belleza y Cuidado Personal ).
# Tiempo de ejecución: 6.1 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 9 de 31 (categoría Cámaras y Accesorios ).
# Tiempo de ejecución: 6.73 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 10 de 31 (categoría Celulares y Teléfonos ).
# Tiempo de ejecución: 7.42 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 11 de 31 (categoría Computación ).
# Tiempo de ejecución: 8.15 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 12 de 31 (categoría Consolas y Videojuegos ).
# Tiempo de ejecución: 8.81 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 13 de 31 (categoría Deportes y Fitness ).
# Tiempo de ejecución: 9.55 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 14 de 31 (categoría Electrodomésticos y Aires Ac. ).
# Tiempo de ejecución: 10.22 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 15 de 31 (categoría Electrónica, Audio y Video ).
# Tiempo de ejecución: 10.93 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 16 de 31 (categoría Entradas para Eventos ).
# Tiempo de ejecución: 11.41 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 17 de 31 (categoría Herramientas y Construcción ).
# Tiempo de ejecución: 12.21 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 18 de 31 (categoría Hogar, Muebles y Jardín ).
# Tiempo de ejecución: 13.12 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 19 de 31 (categoría Industrias y Oficinas ).
# Tiempo de ejecución: 13.76 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 20 de 31 (categoría Inmuebles ).
# Tiempo de ejecución: 14.4 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 21 de 31 (categoría Instrumentos Musicales ).
# Tiempo de ejecución: 15.07 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 22 de 31 (categoría Joyas y Relojes ).
# Tiempo de ejecución: 15.69 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 23 de 31 (categoría Juegos y Juguetes ).
# Tiempo de ejecución: 16.37 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 24 de 31 (categoría Libros, Revistas y Comics ).
# Tiempo de ejecución: 17.4 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 25 de 31 (categoría Música, Películas y Series ).
# Tiempo de ejecución: 18.12 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 26 de 31 (categoría Ropa y Accesorios ).
# Tiempo de ejecución: 18.97 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 27 de 31 (categoría Salud y Equipamiento Médico ).
# Tiempo de ejecución: 19.62 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 28 de 31 (categoría Servicios ).
# Tiempo de ejecución: 20.13 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 29 de 31 (categoría Souvenirs, Cotillón y Fiestas ).
# Tiempo de ejecución: 20.75 minutos.
# ----------------------------------------------------------------------------------------------------
# Recolectando data de la categoría: 30 de 31 (categoría Otras categorías ).
# Tiempo de ejecución: 21.35 minutos.
# ----------------------------------------------------------------------------------------------------
# Tiempo total de ejecución: 21.35 minutos.

# %% [markdown]
# #### Juntamos todo en un sólo dataframe

# %%
df_total_original = pd.concat(lista_dfs, axis = 0)

# %% [markdown]
# #### Corroboramos el tamaño del dataset obtenido

# %%
print("Tamaño total esperado (aprox):", len(lista_categorias) * 1000)
print("Tamaño total:", len(df_total_original))
# Out:
# Tamaño total esperado (aprox): 31000
# Tamaño total: 30843

# %% [markdown]
# #### Eliminamos duplicados

# %%
print("Cantidad de duplicados:", df_total_original.duplicated(keep="first").sum())
df_total_original = df_total_original[~df_total_original.duplicated(keep="first")]
print("Eliminamos los duplicados.")
print("Quedaron", len(df_total_original), "registros en total.")
# Out:
# Cantidad de duplicados: 528
# Eliminamos los duplicados.
# Quedaron 30315 registros en total.

# %% [markdown]
# #### Guardamos en un csv

# %%
df_total_original.to_csv("df_total_original.csv", index = False)
